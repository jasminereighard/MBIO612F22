# %%
library(ggplot2)
library(dplyr)
library(tibble)

# %% [markdown]
# ### Instructions:
#
# 1. it is considered proper programming practice to load all the libraries you need in the first cell of a notebook or at the top of the R-Markdown file. Put all your imports (e.g., `library(ggplot)`) in the cell above.
# 2. Create as many cells as needed to answer a question
#   * Group code that is logically related in the same cell
#   * Keep cells relatively small
#   * Format long statements or expressions, including `ggplot`, across multiple lines
# 3. Submit your work to GitHub under your MBIO repository.
#   * Folder should be called `4_apply_and_data`

# %% [markdown]
# ### Q1
#
# * Write a function called `sd_x` that computes the standard deviation from first principles. Recall that the standard deviation is computed as
#
# $$
# \sigma = \sqrt{\frac{\sum{(x_i - \mu)^2}}{N-1}}
# $$
#
# * $\mu$ is simply the mean of the vector of inputs
#   * it can be computed using the `mean` function
#
#
# For example, given:
#
# ```x = c(1,2,3)```
#
# Since $\mu = 2$, then $\sigma = \sqrt{\frac{(1-2)^2 + (2-2)^2 + (3-2)^2}{3}} = 1$.

# %%
sd_x <- function(x) {
    sqrt(sum((x-mean(x))^2)/(length(x)-1))
}

# %%
example <- c(1,2,3)
sd_x(example)
# Out:
# [1] 1

# %% [markdown]
# ### Q2
# Given the following matrix of data where each column consists of a variable:
# 1. Convert this data frame into a tibble called data_tbl
# 2. Use one of the apply-type of functions in conjunction with `sd_x` you wrote previously to compute the standard deviation for each column.

# %%
data = matrix(1:50, ncol=5)
colnames(data) = c("variable_1", "variable_2", "variable_3", "variable_4", "variable_5")
data
# Out:
#       variable_1 variable_2 variable_3 variable_4 variable_5
#  [1,]  1         11         21         31         41
#  [2,]  2         12         22         32         42
#  [3,]  3         13         23         33         43
#  [4,]  4         14         24         34         44
#  [5,]  5         15         25         35         45
#  [6,]  6         16         26         36         46
#  [7,]  7         17         27         37         47
#  [8,]  8         18         28         38         48
#  [9,]  9         19         29         39         49
# [10,] 10         20         30         40         50

# %%
data_tbl <- as_tibble(data)
apply(data_tbl, 2, sd_x)
# Out:
# variable_1 variable_2 variable_3 variable_4 variable_5
#    3.02765    3.02765    3.02765    3.02765    3.02765

# %% [markdown]
# ### Q3
#
# * In this question, we will build a simulated dataset for healthy and diseased corals.  You will be creating a `tibble` called `coral_health_tbl` that contains 2 columns:
#
# 1. A column called `coral`. Generate this column by sampling 100 coral species from the following values
# ```
# coral_pop = c("Montipora capitata",
#   "Porites compressa",
#   "Porites lobata")
# ```
#  * You can use the function `sample` to select 100 values from the vector `coral_pop`
#    * You can see how the function sample works [here](https://www.rdocumentation.org/packages/base/versions/3.6.2/topics/sample)
#
# 2. The second column is called `is_diseased`.
#     * it represents 100 randomly selected `TRUE` or `FALSE` values that represent whether the coral is healthy or diseased.
#     * Healthy corals (`is_diseased == FALSE`; not diseased) occur with a probability of 0.8, i.e. (`is_diseased == TRUE`) occurs with a probability of 0.2

# %%
coral_pop = c("Montipora capitata",
"Porites compressa",
"Porites lobata")
sample(coral_pop, 100, TRUE)
is_diseased <- c("TRUE", "FALSE")
disease_sample <- sample(is_diseased, 100, TRUE, prob = c(0.8, 0.2))
disease_sample
coral_health_tbl <- as_tibble(cbind(coral_pop, disease_sample))
# Out:
#   [1] "Porites lobata"     "Porites lobata"     "Porites lobata"
#   [4] "Porites lobata"     "Montipora capitata" "Montipora capitata"
#   [7] "Montipora capitata" "Porites lobata"     "Porites lobata"
#  [10] "Porites lobata"     "Porites compressa"  "Porites compressa"
#  [13] "Montipora capitata" "Porites compressa"  "Porites lobata"
#  [16] "Porites compressa"  "Montipora capitata" "Montipora capitata"
#  [19] "Porites compressa"  "Montipora capitata" "Porites lobata"
#  [22] "Montipora capitata" "Porites lobata"     "Porites lobata"
#  [25] "Porites compressa"  "Montipora capitata" "Montipora capitata"
#  [28] "Montipora capitata" "Porites compressa"  "Porites compressa"
#  [31] "Montipora capitata" "Montipora capitata" "Montipora capitata"
#  [34] "Montipora capitata" "Montipora capitata" "Porites compressa"
#  [37] "Porites lobata"     "Porites compressa"  "Porites lobata"
#  [40] "Porites compressa"  "Porites lobata"     "Porites lobata"
#  [43] "Montipora capitata" "Porites compressa"  "Porites compressa"
#  [46] "Montipora capitata" "Porites compressa"  "Porites compressa"
#  [49] "Porites compressa"  "Porites lobata"     "Porites compressa"
#  [52] "Montipora capitata" "Montipora capitata" "Porites compressa"
#  [55] "Porites lobata"     "Porites lobata"     "Porites compressa"
#  [58] "Porites lobata"     "Porites compressa"  "Porites lobata"
#  [61] "Porites compressa"  "Montipora capitata" "Porites lobata"
#  [64] "Montipora capitata" "Porites compressa"  "Porites compressa"
#  [67] "Porites compressa"  "Porites compressa"  "Porites lobata"
#  [70] "Porites lobata"     "Porites compressa"  "Porites compressa"
#  [73] "Porites lobata"     "Porites compressa"  "Montipora capitata"
#  [76] "Porites compressa"  "Montipora capitata" "Porites lobata"
#  [79] "Porites lobata"     "Porites lobata"     "Porites lobata"
#  [82] "Porites compressa"  "Porites compressa"  "Montipora capitata"
#  [85] "Porites compressa"  "Porites lobata"     "Porites compressa"
#  [88] "Porites lobata"     "Montipora capitata" "Porites lobata"
#  [91] "Porites compressa"  "Montipora capitata" "Porites compressa"
#  [94] "Montipora capitata" "Porites lobata"     "Porites compressa"
#  [97] "Montipora capitata" "Porites lobata"     "Porites lobata"
# [100] "Montipora capitata"
#   [1] "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "FALSE" "TRUE"  "TRUE"  "TRUE"
#  [10] "TRUE"  "TRUE"  "TRUE"  "FALSE" "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"
#  [19] "TRUE"  "TRUE"  "TRUE"  "FALSE" "TRUE"  "TRUE"  "FALSE" "TRUE"  "FALSE"
#  [28] "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"
#  [37] "FALSE" "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "FALSE" "TRUE"
#  [46] "TRUE"  "TRUE"  "FALSE" "TRUE"  "TRUE"  "TRUE"  "FALSE" "TRUE"  "TRUE"
#  [55] "TRUE"  "FALSE" "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "FALSE"
#  [64] "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"
#  [73] "TRUE"  "TRUE"  "TRUE"  "TRUE"  "FALSE" "TRUE"  "TRUE"  "TRUE"  "TRUE"
#  [82] "FALSE" "TRUE"  "TRUE"  "TRUE"  "TRUE"  "FALSE" "TRUE"  "FALSE" "FALSE"
#  [91] "TRUE"  "FALSE" "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"  "TRUE"
# [100] "TRUE"
# Warning message in cbind(coral_pop, disease_sample):
# “number of rows of result is not a multiple of vector length (arg 1)”

# %%
length(coral_health_tbl$disease_sample==FALSE)
# Out:
# [1] 100

# %% [markdown]
# ### Q4
#
# * The function `rnorm` is used to sample (i.e., produce) random values from a normal distribution. The syntax of the function is as follows:
# ```
# rnorm(n, mu, sd)
# ```
# where n is the number of samples to generate, mu is the mean of the distribution and `sd` is the standard deviation.
#
# Essentially what the function does is generate `n` random values from a normal distribution that is centered around the mean `mu` and has the standard deviation defined by the parameter `sd`. If you do not understand what this statement means, you should not worry as we will cover it in greater detail in the next section. However, you must know that this function generates n random values that are in some way close to the provided mean (`mu`) you provided.
#
# Use the cell below to experiment with the function `rnorm`. E.g.: try to generate 5 values from the distribution with a mean 10 and a standard deviation 1.

# %%
rnorm(5, 10, 1)
# Out:
# [1]  9.286368 10.511401 10.948947  9.650779  9.741276

# %% [markdown]
# ### Q5
# * Create a new column in `coral_health_tbl` called `coral_cover`. This column represents coral cover values for the corals observed in your tibble
# * For the healthy coral (`is_diseased == FALSE`), sample the cover values from a normal with a mean of 9 and standard deviation of 2
# * For the diseased corals (`health_status = TRUE`), sample the cover values from a normal with mean 1 and std of 3
# * Note that this is a perfect scenario for using `mapply`

# %%
coralcover_fun = function(x){
    if (x == TRUE){
        rnorm(1, mean=1, sd=2)
    }else{
        rnorm(1, mean=9, sd=3)
    }}
coral_health_tbl$coral_cover <- mapply(coralcover_fun, coral_health_tbl$is_diseased)
head(coral_health_tbl)
# Out:
#   Coral              is_diseased coral_cover
# 1 Montipora capitata TRUE         3.00426595
# 2 Porites compressa  TRUE        -0.38962788
# 3 Porites lobata     TRUE         0.06886448
# 4 Montipora capitata TRUE         2.24916759
# 5 Porites compressa  TRUE         0.55966768
# 6 Porites lobata     FALSE       16.43760342

# %% [markdown]
# ### Q6
#
# * Add another column called `binary_health_status`.
#  * set the column to 0 if `is_diseased == FALSE`
#  * set the column to 1 if `is_diseased == TRUE`
#
# * A trick here is to remember that:
#   1. Corecing (converting) a logical can be done with `as.integer()`
#   2. `as.integer(TRUE)` returns 1
#   3. `as.integer(FALSE)` returns 0

# %%
coral_health_tbl %>%
    mutate(binary_health_status = case_when(
    startsWith(is_diseased, "F")~ "0",
    startsWith(is_diseased, "T") ~ "1"
    ))
# Out:
#     Coral              is_diseased coral_cover binary_health_status
# 1   Montipora capitata TRUE         1.03573939 1
# 2   Porites compressa  TRUE         1.72747389 1
# 3   Porites lobata     TRUE         1.39077625 1
# 4   Montipora capitata TRUE        -0.79041707 1
# 5   Porites compressa  TRUE         2.66469057 1
# 6   Porites lobata     FALSE       11.01438237 0
# 7   Montipora capitata TRUE         4.14007307 1
# 8   Porites compressa  TRUE         2.46852925 1
# 9   Porites lobata     TRUE        -0.87739405 1
# 10  Montipora capitata TRUE         1.73660337 1
# 11  Porites compressa  TRUE        -1.19746190 1
# 12  Porites lobata     TRUE         1.57902872 1
# 13  Montipora capitata FALSE       11.11867938 0
# 14  Porites compressa  TRUE         4.77003904 1
# 15  Porites lobata     TRUE         2.88093967 1
# 16  Montipora capitata TRUE        -1.89937712 1
# 17  Porites compressa  TRUE        -1.04220620 1
# 18  Porites lobata     TRUE         4.24870048 1
# 19  Montipora capitata TRUE        -0.70258746 1
# 20  Porites compressa  TRUE         0.13567949 1
# 21  Porites lobata     TRUE         1.38160213 1
# 22  Montipora capitata FALSE        8.15080486 0
# 23  Porites compressa  TRUE         1.72568451 1
# 24  Porites lobata     TRUE         0.20912982 1
# 25  Montipora capitata FALSE        8.69083536 0
# 26  Porites compressa  TRUE        -0.09228816 1
# 27  Porites lobata     FALSE        5.40940221 0
# 28  Montipora capitata TRUE        -0.76329513 1
# 29  Porites compressa  TRUE        -1.92603705 1
# 30  Porites lobata     TRUE        -3.18699919 1
# ⋮   ⋮                  ⋮           ⋮           ⋮
# 71  Porites compressa  TRUE        -0.4554269  1
# 72  Porites lobata     TRUE         1.8036521  1
# 73  Montipora capitata TRUE         4.3700871  1
# 74  Porites compressa  TRUE         1.1933002  1
# 75  Porites lobata     TRUE         0.8530297  1
# 76  Montipora capitata TRUE         0.8921520  1
# 77  Porites compressa  FALSE        9.4465130  0
# 78  Porites lobata     TRUE         0.7884936  1
# 79  Montipora capitata TRUE         2.3444499  1
# 80  Porites compressa  TRUE         1.3436600  1
# 81  Porites lobata     TRUE        -1.7714752  1
# 82  Montipora capitata FALSE        9.7000091  0
# 83  Porites compressa  TRUE         0.8562113  1
# 84  Porites lobata     TRUE         3.0173885  1
# 85  Montipora capitata TRUE         2.8945363  1
# 86  Porites compressa  TRUE         1.4933022  1
# 87  Porites lobata     FALSE        8.9446188  0
# 88  Montipora capitata TRUE         1.5078416  1
# 89  Porites compressa  FALSE        6.6341916  0
# 90  Porites lobata     FALSE       10.4629986  0
# 91  Montipora capitata TRUE         0.9994676  1
# 92  Porites compressa  FALSE       10.6007568  0
# 93  Porites lobata     TRUE         3.3043232  1
# 94  Montipora capitata TRUE        -1.2926489  1
# 95  Porites compressa  TRUE        -0.1946705  1
# 96  Porites lobata     TRUE         0.9992895  1
# 97  Montipora capitata TRUE         0.9605161  1
# 98  Porites compressa  TRUE        -0.4740773  1
# 99  Porites lobata     TRUE        -0.9316558  1
# 100 Montipora capitata TRUE        -0.1948486  1

# %% [markdown]
# ### Q7
#
# * Plot the distribution of `coral_cover` for healthy versus diseased corals
# * Note that I am using the histogram `geom`
#   * Histograms need only an `x`-axis because the `y` is typically computed as the number of items occurring in a bin of some predetermined width.
#     * However, instead of a raw count, we want a normalized count. You can normalize the count by setting `y = stat(count / sum(count))`
#   * I am coloring the bin outlines in black and filling in grey for disease and white for healthy
#   * I am using `binwidth=1'.
# * Use the `labs` function to add a title and to change the labels for the `x` and `y` axes
# * The plot should look "somewhat" like the following
# ![](https://www.dropbox.com/s/wdbdj05rd50vb0k/healthy-diseased.png?dl=1)

# %%
coralhis <- ggplot(coral_data, aes(x = coral_cover, y = stat(count / sum(count)), fill = is_diseased)) +
            geom_histogram(color = "black", binwidth=1) +
    scale_fill_manual(values = c("#FFFFFF", "#7E7E7E")) +
 labs(
        title = "Total Coral Coverage (Healthy vs. Diseased)",
        x = "Coral Cover",
        y = "Normalized proportion",
        fill = 'Health Status'
      ) 
coralhisto <- coralhis +
    theme(text = element_text(size = 16))

# %%
coralhisto
# Out:
# plot without title

# %% [markdown]
# ### Q8
#
# * Use `geom_density` to mirror the information conveyed in the histogram above using density curves instead of histograms.
#   * Set the `adjust` parameter of `geom_density` to `2`
# * Change the `xlim` scale so that we can see the edges of the curves
#   * I.e., curves should not be cut off
#
# * The resulting curve will look like the following
# ![](https://www.dropbox.com/s/rs4rx0w6ur8p5wq/coral_distr_practical.png?dl=1)

# %%
coralden <- ggplot(coral_data, aes(x = coral_cover, y = stat(count / sum(count)), fill = is_diseased)) +
            geom_density(adjust=2, alpha=0.5) +
            scale_x_continuous(limits = c(-10, 19)) + 
scale_fill_manual(values = c("#FFFFFF", "#7E7E7E")) +
 labs(
        title = "Total Coral Coverage (Healthy vs. Diseased)",
        x = "Coral Cover",
        y = "Normalized proportion",
        fill = 'Health Status'
      )

coraldensity <- coralden +
    theme(text = element_text(size = 14))

# %%
coraldensity
# Out:
# plot without title

# %% [markdown]
# ### Q9
#
# You have been provided with the dataset illustrated in the image below, which contains counts for 20 fish species across 5 locations. For convenience, only two species and 2 locations are illustrated here. Based on your knowledge of tidy data, how can you format the data shown in this file in a way that is considered `tidy`. Provide an image of a hand-drawn table (or tables if needed) that represents the table format. Briefly justify your answer in a 3-4 sentences.
#
#
# ![](https://www.dropbox.com/s/ucvj0gburg8at60/tidy_data.png?dl=1)

# %% [markdown]
# #### Multiple variables are stored in one column (Genus_name/Species_name).
# #### While the column name is serparated by characters, tidy data would require splitting into two seperate columns so that each variable forms a column and each observation forms a row.
# #### I also added the location ID as a seperate column as well to include it as a variable within the table.
# #### As the two tables are of the same observational unit, the data sets form one table.

# %% [markdown]
# ![Fish_data.png](attachment:Fish_data.png)
